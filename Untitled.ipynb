# %%
import pandas as pd

# %%
staff = pd.read_csv('health-care-staff-by-emirate-sector-gender-and-job-category-ds.csv')

# %%
staff
# Out:
#      Year         Emirate En         Emirate Ar         Geo Coordinates  \
# 0    2018          Abu Dhabi            أبو ظبي  24.4539° N, 54.3773° E
# 1    2018          Abu Dhabi            أبو ظبي  24.4539° N, 54.3773° E
# 2    2018          Abu Dhabi            أبو ظبي  24.4539° N, 54.3773° E
# 3    2018          Abu Dhabi            أبو ظبي  24.4539° N, 54.3773° E
# 4    2018              Dubai                دبي  25.2048° N, 55.2708° E
# ..    ...                ...                ...                     ...
# 715  2011  Northern Emirates  الامارات الشمالية                     NaN
# 716  2011          Abu Dhabi            أبو ظبي  24.4539° N, 54.3773° E
# 717  2011          Abu Dhabi            أبو ظبي  24.4539° N, 54.3773° E
# 718  2011              Dubai                دبي  25.2048° N, 55.2708° E
# 719  2011              Dubai                دبي  25.2048° N, 55.2708° E
#
#       Sector En Sector Ar  Category En Category Ar Gender En Gender Ar   Total
# 0    Government     حكومي    Physician        طبيب      Male       ذكر  2415.0
# 1    Government     حكومي    Physician        طبيب    Female      انثي  1798.0
# 2       Private       خاص    Physician        طبيب      Male       ذكر  3507.0
# 3       Private       خاص    Physician        طبيب    Female      انثي  2037.0
# 4    Government     حكومي    Physician        طبيب      Male       ذكر   973.0
# ..          ...       ...          ...         ...       ...       ...     ...
# 715     Private      خاص   Technicians       فنيون    Unkown  غير مبين     NaN
# 716  Government     حكومي  Technicians       فنيون    Unkown  غير مبين  2032.0
# 717     Private       خاص  Technicians       فنيون    Unkown  غير مبين  3616.0
# 718  Government     حكومي  Technicians       فنيون    Unkown  غير مبين  1577.0
# 719     Private       خاص  Technicians       فنيون    Unkown  غير مبين  2492.0
#
# [720 rows x 11 columns]

# %%
staff = staff[['Year','Emirate En','Sector En','Category En','Gender En','Total']]

# %%
staff = staff.rename(columns={'Year':'year','Emirate En':'district', 'Sector En': 'sector', 'Category En': 'category','Gender En':'gender','Total':'total'})

# %%
#staff = staff.dropna(subset=['hospitals'])

# %%
staff
# Out:
#      year           district      sector     category  gender   total
# 0    2018          Abu Dhabi  Government    Physician    Male  2415.0
# 1    2018          Abu Dhabi  Government    Physician  Female  1798.0
# 2    2018          Abu Dhabi     Private    Physician    Male  3507.0
# 3    2018          Abu Dhabi     Private    Physician  Female  2037.0
# 4    2018              Dubai  Government    Physician    Male   973.0
# ..    ...                ...         ...          ...     ...     ...
# 714  2011  Northern Emirates  Government  Technicians  Unkown  1802.0
# 716  2011          Abu Dhabi  Government  Technicians  Unkown  2032.0
# 717  2011          Abu Dhabi     Private  Technicians  Unkown  3616.0
# 718  2011              Dubai  Government  Technicians  Unkown  1577.0
# 719  2011              Dubai     Private  Technicians  Unkown  2492.0
#
# [719 rows x 6 columns]

# %%
staff['total'] =staff['total'].astype(int)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
staff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 719 entries, 0 to 719
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   year      719 non-null    int64
#  1   district  719 non-null    object
#  2   sector    719 non-null    object
#  3   category  719 non-null    object
#  4   gender    719 non-null    object
#  5   total     719 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 39.3+ KB

# %%
staff_district=staff.copy()
staff_district_unique=staff_district.drop_duplicates(subset=['district'])
list_D = staff_district_unique['district'].to_numpy()
options_D = col3.selectbox('Select the District to see its health staff:', list_D)
st.write(options_D)
options_D_df=pd.DataFrame(options_D, columns = ['district'])

# %%
staff_district=staff.copy()
staff_district_unique=staff_district.drop_duplicates(subset=['district'])
list_D = staff_district_unique['district'].to_numpy()

# %%
list_D
# Out:
# array(['Abu Dhabi', 'Dubai', 'Sharjah', 'Ajman', 'Umm Al Quwain',
#        'Ras Al Khaima', 'Fujairah', 'Northern Emirates'], dtype=object)

# %%
options_D=[]

# %%
options_D.inf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-3c29dd41650a> in <module>
# ----> 1 options_D.info()
#
# AttributeError: 'list' object has no attribute 'info'
